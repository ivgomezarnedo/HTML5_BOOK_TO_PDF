# %%
import urllib.request
url="https://ebooks.enfermeria21.com/ebooks/-html5-dev/189/files/assets/common/page-vectorlayers/{0}.svg?uni=10198dcd85045ceb9709810f97b12ff7"
number=1
for number in range(1,517):
    print('%04d' % number)
    url_page=url.format('%04d' % number)
    try:
        urllib.request.urlretrieve(url_page, "Ultraresumenes/{0}.svg".format('%04d' % number))
    except Exception as ex:
        print("URL NOT FOUND: {0}".format(url_page))
        continue
# Out:
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# URL NOT FOUND: https://ebooks.enfermeria21.com/ebooks/-html5-dev/189/files/assets/common/page-vectorlayers/0097.svg?uni=10198dcd85045ceb9709810f97b12ff7
# 0098
# URL NOT FOUND: https://ebooks.enfermeria21.com/ebooks/-html5-dev/189/files/assets/common/page-vectorlayers/0098.svg?uni=10198dcd85045ceb9709810f97b12ff7
# ...

# %%
from svglib.svglib import svg2rlg
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
drawing = svg2rlg("Ultraresumenes/0013.svg")
# Out:
# Unable to find a clipping path with id clippath0
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# ...

# %%
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
renderPM.drawToFile(drawing, "file.png", fmt="PNG")

# %%
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF, renderPM
drawing = svg2rlg("Ultraresumenes/0013.svg")
renderPM.drawToFile(drawing, "file.png", fmt="PNG")
# Out:
# Unable to find a clipping path with id clippath0
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:g_d0_f1', weight:normal, style:normal
# ...

# %%
import pyvips

image = pyvips.Image.new_from_file("Ultraresumenes/0013.svg", dpi=300)
image.write_to_file("test.png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Programas\Anaconda3\lib\site-packages\pyvips\__init__.py in <module>
#      18 try:
# ---> 19     import _libvips
#      20
#
# ModuleNotFoundError: No module named '_libvips'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-0955ddeb5912> in <module>
# ----> 1 import pyvips
#       2
#       3 image = pyvips.Image.new_from_file("Ultraresumenes/0013.svg", dpi=300)
#       4 image.write_to_file("test.png")
#
# ~\Programas\Anaconda3\lib\site-packages\pyvips\__init__.py in <module>
#      68
#      69     # possibly use ctypes.util.find_library() to locate the lib?
# ---> 70     gobject_lib = ffi.dlopen(_gobject_libname)
#      71     vips_lib = ffi.dlopen(_vips_libname)
#      72     if _glib_libname:
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import chromedriver_binary # If you're using conda like me.
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
import sys
import urllib.request
import re
import json
chrome_options = webdriver.ChromeOptions()
settings = {"recentDestinations": [{"id": "Save as PDF", "origin": "local", "account": ""}], "selectedDestinationId": "Save as PDF", "version": 2}
prefs = {'printing.print_preview_sticky_settings.appState': json.dumps(settings)}
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--kiosk-printing')
caps = DesiredCapabilities.CHROME
driver = webdriver.Chrome(ChromeDriverManager().install(),desired_capabilities=caps,chrome_options=chrome_options)
driver.get("file:///C:/Users/GOMEZAI/Desktop/C%C3%B3digo/Ultraresumenes/0019.svg")
driver.execute_script('window.print();')
driver.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [C:\Users\GOMEZAI\.wdm\drivers\chromedriver\win32\93.0.4577.15\chromedriver.exe] found in cache
# C:\Users\GOMEZAI\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: use options instead of chrome_options
